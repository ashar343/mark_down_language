# %% [markdown]
# **Student Name** is Ashar Jalani
# **Instructor Name** Dr Aammar
# Date 03,10, 2023
# ================================Assignment No 2====================================
#
#             **Types Of AI**
#
# There are many fields whare AI is Use
# But hare We talk about Data Science
#
# AI devided into two parts
# In Fist Part Mainly Three Types of AI
#             ✅Narrow AI / Week AI
#             ✅Generatl AI
#             ✅Strong AI / Super AI
#
#
# In Second Part 4 types Of AI
#             ✅Reactive Machine
#             ✅Limited Memory
#             ✅Theory Of Mind
#             ✅Self AwareNess
#
#
#
# =======================Data Science and Data Anlytical==================================
#
# **Data Science**      =
# ✅Explore DAta
# ✅Arrive Business and Consuling By using Advance Level Data
# ✅Responsable clean and Processing data Using tools
# ✅Evulate Advance Models to work on big data
# ✅Bulid Machine Learning Models
#    Basic Requriments
# ✅is You must HAve a Bachular Dagree
# ✅Good Experience in Data anlysical
# ✅Microsoft Excel , Python , java, C++ etc Knowledge
# ✅
#
#
#                      **Data Anlytical**
#
# ✅Understand Company Goals Requriments Business problems
# ✅They Gather DAta
# ✅Write Coplex SQL Quries and scripts to grather infomation
# ✅Filtr and Clean data
# ✅Create Summery repots
#     Basic requriments
# ✅Have degree in Statices and dEconomic and MS Excel
# ✅Java , Python and R Lanuages
# ✅You must have a Knowledge to ML and Algorithms
# ✅Must Presention Skills
#
#
#
#
# ==============Big Players In AI field and litle bit info about there===========
#
# Google
# Microsoft
# IBM
# Intel
# Amazon
# Baidu
# Facebook
# Apple
# Qualcomm
# Huawei
#
# ==============How Goolgle Play In AI field==========================
# Google Search is Also Use AI algorithms
# and Youtube , Goolge Maps, Drive, Goolge translater and other
# and Now Google bard
# bard is Large Language Model (LLM)
# I provide 81 96 Tokens
#
#
#
# =============How Amazon Play In AI field==========================
# Amazon Web Services will offer access to its own first-party language models called Titan
#
#
# =============How Microsoft Play In AI field==========================
#
# Using Bing AI which is Large language m,odel and base on GPT 4
